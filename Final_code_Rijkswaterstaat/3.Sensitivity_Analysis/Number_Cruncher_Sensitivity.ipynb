# %% [markdown]
# # Number Cruncher Sensitivity Analysis
#
# This notebook is specifically designed for performing sensitivity analysis across a large set of days and different settings. The primary objective is to determine the optimal parameter settings for aggregating and combining results from various days. The sensitivity analysis enables us to fine-tune the parameters, ensuring the best possible outcome in the final solution.
#
# For a detailed description of the sensitivity analysis model and its workings, we recommend referring to the “Main_Combine_results_optimisation” notebook.

# %% [markdown]
# # Calibration / Sensitivity Analysis
#
# # Instructions please read carefully
#
# 1. copy the settings provide for you into the cell with settings
# 2. make sure the result folder is empty, if not delete those files
# 3. Change the path such that it can save a file in the results folder
# 4. test if path works
# 5. set your settings so that your laptop will never enter sleep mode, this will stop the calculations
# 6. press Kernel -> Restart & Run all

# %%
pip install pygeos
# Out:
# Requirement already satisfied: pygeos in c:\users\klaas sicking\documents\studie\studie\aerospace\advanced data science\pro\venv\lib\site-packages (0.14)
# Requirement already satisfied: numpy>=1.13 in c:\users\klaas sicking\documents\studie\studie\aerospace\advanced data science\pro\venv\lib\site-packages (from pygeos) (1.26.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install fuzzywuzzy
# Out:
# Requirement already satisfied: fuzzywuzzy in c:\users\klaas sicking\documents\studie\studie\aerospace\advanced data science\pro\venv\lib\site-packages (0.18.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import functions
import folium
import pandas as pd 
import geopandas as gpd 
import numpy as np
import networkx as nx
import ast
from fuzzywuzzy import fuzz
from datetime import datetime
import matplotlib.pyplot as plt 
import math
import shapely.wkt
import time
from gurobipy import *
from functions import DutchRDtoWGS84
import warnings
import matplotlib.pyplot as plt
warnings.simplefilter("ignore")
# %matplotlib notebook

# %% [markdown]
# ### Load the data

# %%
unique_candidates = pd.read_csv('input/unique_candidates.csv')
df = pd.read_csv('input/weight.csv')
# Read the road network shapefile into a GeoDataFrame
gdf = gpd.read_file('input/Snelheid_Wegvakken.shp')
road_network = gdf
G = nx.read_graphml("input/highway_nodes_DiGraph_nb.xml")
all_incidents = pd.read_csv("input/Incidents_clean.csv")
all_incidents['starttime_new'] = pd.to_datetime(all_incidents['starttime_new'])

df_without_weight = pd.read_csv('input/result.csv')
sums_without_weight = df_without_weight.drop(['Date'], axis=1).sum()
df_with_weight = pd.read_csv('input/weight.csv')
sums_with_weight = df_with_weight.drop(['Date', 'Event_Count'], axis=1).sum()

# %% [markdown]
# ### Select your settings and paste below
# ##### Klaas
# sums = sums_with_weight
# name = 'with_weight'
# number_of_inspectors = 120
# min_ranges = [0, 5000, 7500, 10000, 12500, 15000, 175000]
# min_direct_ranges = [0, 2000, 3000, 4000, 5000, 6000, 7000]
#
# ##### Heisuke
# sums = sums_with_weight
# name = 'with_weight'
# number_of_inspectors = 110
# min_ranges = [0, 5000, 7500, 10000, 12500, 15000, 175000]
# min_direct_ranges = [0, 2000, 3000, 4000, 5000, 6000, 7000]
#
# #### Yixin
# sums = sums_with_weight
# name = 'with_weight'
# number_of_inspectors = 100
# min_ranges = [0, 5000, 7500, 10000, 12500, 15000, 175000]
# min_direct_ranges = [0, 2000, 3000, 4000, 5000, 6000, 7000]
#
# #### Martin
# sums = sums_without_weight
# name = 'without_weight'
# number_of_inspectors = 120
# min_ranges = [0, 5000, 7500, 10000, 12500, 15000, 175000]
# min_direct_ranges = [0, 2000, 3000, 4000, 5000, 6000, 7000]
#
# #### Martijn
# sums = sums_without_weight
# name = 'without_weight'
# number_of_inspectors = 110
# min_ranges = [0, 5000, 7500, 10000, 12500, 15000, 175000]
# min_direct_ranges = [0, 2000, 3000, 4000, 5000, 6000, 7000]
#
# #### Klaas 2
# sums = sums_without_weight
# name = 'without_weight'
# number_of_inspectors = 100
# min_ranges = [0, 5000, 7500, 10000, 12500, 15000, 175000]
# min_direct_ranges = [0, 2000, 3000, 4000, 5000, 6000, 7000]

# %%
# Example of settings for Klaas
sums = sums_with_weight
name = 'with_weight'
number_of_inspectors = 120
min_ranges = [0, 5000, 7500, 10000, 12500, 15000, 175000]
min_direct_ranges = [0, 2000, 3000, 4000, 5000, 6000, 7000]

# %%
file_path = "result/"

# %% [markdown]
# ### Test the file_path

# %%
# Your string to be saved
my_string = "This is the string I want to save to a text file."

with open(file_path + "test_file.txt", 'w') as file:
    file.write(my_string)

print(f"String saved to {file_path}")
print('Check if the text file is in the right folder!!!')
# Out:
# String saved to result/
# Check if the text file is in the right folder!!!

# %% [markdown]
# ## You have nothing to change below this line

# %%
# days for calibration
calibration_days = ['2019-07-31', '2019-08-12', '2019-08-15', '2019-08-16',
       '2019-08-29', '2019-09-04', '2019-09-19', '2019-09-20',
       '2019-10-01', '2019-10-08', '2019-10-09', '2019-10-22',
       '2019-11-05', '2019-11-07', '2019-11-14', '2019-11-19',
       '2019-11-22', '2019-12-06', '2019-12-26', '2019-12-30']

input_days = calibration_days

# %% [markdown]
# ### Optimal Location Selection Functions
# These functions are used to find and select optimal locations while exploring different parameter settings.

# %%
def get_score_and_location_lists(sums_df, unique_candidates_df=unique_candidates):
    """
    Convert a matrix (sums_df) containing scores for selected locations into two lists:
    
    1. A score list: A list of scores for each selected location.
    2. A location list: A list of tuples, each containing the x and y coordinates of a selected location.

    Args:
        sums_df (DataFrame): A DataFrame containing the scores for selected locations.
        unique_candidates_df (DataFrame, optional): A DataFrame with information about the selected locations. Defaults to 'unique_candidates'.

    Returns:
        list: A list of scores for each selected location.
        list: A list of location tuples (x, y) for each selected location.
    """
    sum_df = sums_df.reset_index()
    sum_df.columns = ['Index', 'Sum']

    results_df = unique_candidates_df.copy()
    combined_df = pd.concat([results_df, sum_df], axis=1)
    combined_df = combined_df.sort_values(by='Sum', ascending=False)
    combined_df = combined_df.drop(columns='Index')

    score_list = combined_df['Sum'].tolist()
    location_df = combined_df[['first_point_x', 'first_point_y']]
    location_list = list(location_df.to_records(index=False))
    return score_list, location_list

# %%
def find_closest_node(graph, target_node):
    """
    Find the closest matching node in a given graph for a target node name.

    This function calculates the similarity between the target node name and each node in the graph
    and returns the node with the highest similarity score.

    Args:
        graph (networkx.Graph): The graph containing nodes to search for a match.
        target_node (str): The target node name for which to find the closest match.

    Returns:
        str: The node name from the graph that best matches the target node name.
    """
    closest_node = None
    max_similarity = -1

    for node in graph.nodes:
        similarity = fuzz.token_sort_ratio(target_node, node)
        if similarity > max_similarity:
            closest_node = node
            max_similarity = similarity

    return closest_node

# %%
def find_optimal_locations(G, score_list, location_list, max_range, max_direct_range, number_of_inspectors):
    """
    Selects a specified number of locations with the highest scores while considering constraints on minimum Euclidean and direct distances.


    Args:
        G (networkx.Graph): The graph representing the area where inspection locations are selected.
        score_list (list): A list of scores for each location.
        location_list (list): A list of location coordinates (x, y).
        max_range (float): The maximum allowed Euclidean distance between selected locations.
        max_direct_range (float): The maximum allowed direct (straight-line) distance between selected locations.
        number_of_inspectors (int): The desired number of inspection locations to select.

    Returns:
        list: A list of selected optimal inspection locations, each represented as a tuple (x, y).
        list: A list of scores corresponding to the selected locations.
    """
    final_locations = []
    Sum = []

    for item in range(len(score_list)):
        extent = location_list[item]

        if not str(extent) in G:
            extent = find_closest_node(G, extent)
            extent = ast.literal_eval(extent)

        costs = [1e6]
        direct_costs = [1e6]

        for loc in final_locations:
            direct_cost = ((loc[0] - extent[0])**2 + (loc[1] - extent[1])**2) ** (1/2)
            direct_costs.append(direct_cost)

            try:
                cost = nx.shortest_path_length(G, str(extent), str(loc), weight='weight')
            except:
                cost = 1e6
            costs.append(cost)

            try:
                cost = nx.shortest_path_length(G, str(loc), str(extent), weight='weight')
            except:
                cost = 2e6
            costs.append(cost)

        min_cost = min(costs)
        min_direct_cost = min(direct_costs)

        if (min_cost > max_range) and (min_direct_cost > max_direct_range):
            final_locations.append(extent)
            Sum.append(score_list[item])
        # else:
        #     print('Location is too close')

        if len(final_locations) == number_of_inspectors:
            break

    return final_locations, Sum

# %%
def process_final_locations(final_locations, Sum):
    """
    Convert lists of final inspection locations and corresponding scores into a DataFrame.

    Args:
        final_locations (list of tuples): A list of tuples representing inspection locations with (x, y) coordinates.
        Sum (list): A list of scores corresponding to each inspection location.

    Returns:
        pd.DataFrame: A DataFrame containing columns for 'X_value' (x-coordinate), 'Y_value' (y-coordinate), and 'Sum_weight' (score).
    """
    data = final_locations
    x, y = zip(*data)
    x_values = list(x)
    y_values = list(y)
    
    # # Assuming you have the 'DutchRDtoWGS84' function defined elsewhere
    # wgs_coords = [functions.DutchRDtoWGS84(x, y) for x, y in zip(x_values, y_values)]
    # wgs_x_values, wgs_y_values = zip(*wgs_coords)
    
    Inspector_locations = pd.DataFrame({'X_value': x_values, 'Y_value': y_values, 'Sum_weight': Sum})
    display(Inspector_locations)
    return Inspector_locations

# %%
def other_road_side(node, G):
    """
    Create a new graph containing only nodes on the opposite road side.

    This function takes a node in a graph (G) and identifies its corresponding road side (RPE_CODE). It then creates a new graph (RPE_G) that includes only nodes with the opposite road side value, such as 'L' for 'R' or 'R' for 'L'. If the node's road side is '#' or if there are no nodes on the opposite road side, it returns None.

    Args:
        node: A node in the input graph G.
        G (networkx.Graph): The original graph containing road-side information.

    Returns:
        networkx.Graph or None: A new graph containing nodes on the opposite road side or None if there are no such nodes.
    """
    RPE = G.nodes[node]['RPE_CODE']
    if RPE == "L":
        value_to_match = "R"
    if RPE == "R":
        value_to_match = "L"
    if RPE == "#":
        return None
    selected_nodes = []
    for node in G.nodes:
        RPE = G.nodes[node]['RPE_CODE']
        if RPE == value_to_match:
            selected_nodes.append(node)
    RPE_G = nx.Graph()
    RPE_G.add_nodes_from(selected_nodes)
    return RPE_G

# %%
def find_closest_node_other_side(graph, x1, y1):
    """
    Find the closest node in a given graph based on Euclidean distance. (Used for finding the closest node on the other side of the road)

    This function calculates the Euclidean distance between a specified point (x1, y1) and each node in the graph. It returns the node from the graph that is closest to the specified point, along with the calculated minimum distance.

    Args:
        graph (networkx.Graph): The graph containing nodes to search for the closest node.
        x1 (float): The x-coordinate of the specified point.
        y1 (float): The y-coordinate of the specified point.

    Returns:
        str: The node in the graph that is closest to the specified point.
        float: The minimum Euclidean distance between the specified point and the closest node.
    """
    closest_node = None
    min_distance = float('inf')
    for node in graph.nodes:
        x2, y2 = functions.parse_coordinate(node)
        distance = math.sqrt((x1 - x2) ** 2 + (y1 - y2) ** 2)

        if distance < min_distance:
            closest_node = node
            min_distance = distance

    return closest_node, min_distance

# %%
def create_clones(graph, node, max_range = 500):
    """
    Create clone inspector locations on the opposite side of the road for a selected inspector location.

    Args:
        graph (networkx.Graph): The graph containing road-side information and nodes.
        node: The selected inspector location node.
        max_range (float): The maximum range within which the clone inspector location must be located on the opposite side of the road. Defaults to 500.

    Returns:
        tuple or None: A tuple representing the clone inspector location (x, y) if within max_range, or None if not.
    """
    node = find_closest_node(graph, str(node))
    x, y = functions.parse_coordinate(node)
    RPE_G = other_road_side(node, graph)
    if RPE_G == None:
        return None
    RPE_node, RPE_sim = find_closest_node_other_side(RPE_G, x, y)
    if RPE_sim < max_range:
        x_str, y_str = str(RPE_node).strip('()').split(', ')
        RPE_node_x, RPE_node_y = (float(x_str), float(y_str))
        return (RPE_node_x, RPE_node_y)  
    else:
        return None

# %%
def final_Inspector_locations(sums, number_of_inspectors, min_range, min_direct_range, G=G):
    """
    Generate the final list of inspector locations based on optimization and clone creation.

    Args:
        sums (DataFrame): A DataFrame containing scores for potential inspector locations.
        number_of_inspectors (int): The desired number of inspector locations to select.
        min_range (float): The minimum allowed Euclidean distance between selected locations.
        min_direct_range (float): The minimum allowed direct (straight-line) distance between selected locations.
        G (networkx.Graph, optional): The graph representing the area. Defaults to G.

    Returns:
        pd.DataFrame: A DataFrame containing the selected inspector locations and their clone locations on the opposite side of the road.
    """
    score_list, location_list = get_score_and_location_lists(sums)
    final_locations, Sum = find_optimal_locations(G, score_list, location_list, min_range, min_direct_range, number_of_inspectors)
    Inspector_locations = process_final_locations(final_locations, Sum)
    
    # Assuming Inspector_locations is a DataFrame
    Inspector_locations['Other_side'] = Inspector_locations.apply(lambda row: create_clones(G, f"({row['X_value']}, {row['Y_value']})"), axis=1)
    return (Inspector_locations)

# %% [markdown]
# ### Calibration Functions
# These functions are designed for performing calibration and determining the optimal parameter settings.

# %%
def filter_incidents(select_day, inc_df):
    """
    Filter and preprocess incidents for a selected day from the total incidents DataFrame.

    Args:
        select_day (datetime.date): The date for which incidents will be filtered.
        inc_df (pd.DataFrame): The total incidents DataFrame containing incident data.

    Returns:
        pd.DataFrame: A filtered and preprocessed DataFrame with incidents that occurred on the selected day. The DataFrame is prepared for future calculations with additional columns.
    """
    
    # filter to incidents which happened on selected_day
    filt_inc = inc_df[inc_df['starttime_new'].dt.date == select_day]
    filt_inc = filt_inc.copy()

    # add dutch rd coordinates
    DutchRD = filt_inc.apply(lambda x: functions.WGS84toDutchRD(x.primaire_locatie_lengtegraad, 
                                                                x.primaire_locatie_breedtegraad), axis=1)
    filt_inc['dutch_rd_x'] = DutchRD.apply(lambda x: x[0])
    filt_inc['dutch_rd_y'] = DutchRD.apply(lambda x: x[1])

    # add columns to the DF which will be used later
    filt_inc['Node'] = None
    filt_inc['Node_distance_to_incident'] = None
    filt_inc['Node_distance_line'] = None
    filt_inc['Node_line'] = None
    filt_inc['Node_RPE'] = None

    return filt_inc

# %%
def find_nearest_node_incidents_new(x, y, gdf, tolerance=25):
    """
    Find the nearest linestring in a GeoDataFrame to a given point (x, y) and calculate distances.

    This function takes a point with coordinates (x, y) and a GeoDataFrame (gdf) containing linestrings. It determines which linestring from the network is located closest to the specified point and calculates the distance to that linestring. It also checks if the point is within a specified tolerance distance to the nearest linestring.

    Args:
        x (float): The x-coordinate of the point.
        y (float): The y-coordinate of the point.
        gdf (geopandas.GeoDataFrame): The GeoDataFrame containing linestrings.
        tolerance (float, optional): The tolerance distance within which the point is considered to be on the nearest linestring. Defaults to 25.

    Returns:
        dict: A dictionary containing information about the nearest linestring and distances, including:
            - 'Node': The nearest node coordinates.
            - 'Line': The nearest linestring.
            - 'RPE': The road-side information of the nearest linestring.
            - 'Total Distance to Line': The total distance to the nearest linestring.
            - 'Distance to Incident': The Euclidean distance from the point to the nearest node on the linestring.
            If the point is not within the tolerance distance, the dictionary values are set to None.
    """
    point = f"POINT ({x} {y})"
    
    # create a gdf of the point and all lines in the network
    gdf_line = gpd.GeoDataFrame(gdf['geometry'])
    
    # crs is determined by the crs of the linestrings in the network
    gdf_point = gpd.GeoDataFrame(geometry=[shapely.wkt.loads(point)], crs=gdf_line.crs)
    
    # finds the nearest linestring and merges the two gdf's together
    df_n = gpd.sjoin_nearest(gdf_point, gdf_line).merge(gdf_line, left_on="index_right", right_index=True)
    
    # calculates the distance from the point to the linestring
    df_n['distance'] = df_n.apply(lambda r: r["geometry_x"].distance(r["geometry_y"]), axis=1)
    
    # if two or more linestrings are at an equal distance from the point it only considers the first linestring
    if len(df_n) > 1:
        df_n = pd.DataFrame(df_n.iloc[0]).T
        df_n = gpd.GeoDataFrame(df_n, geometry='geometry_y', crs=gdf_line.crs)
    
    # checks whether the point is located within the tolarance distance
    if df_n['distance'].min() < tolerance:
        
        # I copied this from Klaas, I'm not sure why he takes the last coordinate
        nearest_node = df_n['geometry_y'].item().coords[-1]
        nearest_line = df_n['geometry_y'].item()
        nearest_RPE = gdf.iloc[df_n['index_right']]['RPE_CODE'].item()
        total_distance_to_nearest_line = gdf.iloc[df_n['index_right']]['ENDAFSTAND'].item()
        distance_to_incident = np.sqrt((nearest_node[0] - x) ** 2 + (nearest_node[1] - y) ** 2)

        return {'Node': nearest_node,
                'Line': nearest_line,
                'RPE': nearest_RPE,
                'Total Distance to Line': total_distance_to_nearest_line,
                'Distance to Incident': distance_to_incident}
    
    # if the point is not within the tolarance distance it returns an empyt dict
    else:
        return {'Node': None,
                'Line': None,
                'RPE': None,
                'Total Distance to Line': None,
                'Distance to Incident': None}

# %%
def calculate_values(row):
    """
    Calculate and store values related to the nearest node and linestring for an incident.

    Args:
        row (pd.Series): A row from the incidents DataFrame containing incident data.
        gdf (geopandas.GeoDataFrame): The GeoDataFrame containing linestrings for the network.

    Returns:
        pd.Series: The input row with additional columns storing calculated values, including:
            - 'Node': The nearest node coordinates.
            - 'Node_distance_line': The total distance to the nearest linestring.
            - 'Node_line': The nearest linestring.
            - 'Node_distance_to_incident': The Euclidean distance from the incident to the nearest node.
            - 'Node_RPE': The road-side information of the nearest linestring.
    """

    x = row['dutch_rd_x']
    y = row['dutch_rd_y']
    result = find_nearest_node_incidents_new(x, y, gdf)
    
    row["Node"] = result['Node']
    row["Node_distance_line"] = result['Total Distance to Line']
    row["Node_line"] = result['Line']
    row['Node_distance_to_incident'] = result['Distance to Incident']
    row['Node_RPE'] = result['RPE']
    
    return row

# %%
def drop_inc_out_of_range(inc_df, print_bool=False):
    """
    Drop incidents that are more than 25 meters from the nearest network link.

    Args:
        inc_df (pd.DataFrame): The incidents DataFrame.
        print_bool (bool, optional): If True, the function prints the percentage of dropped rows. Defaults to False.

    Returns:
        pd.DataFrame: A DataFrame containing incidents that are within 25 meters of the nearest road network link.
    """
    
    nan_count = inc_df['Node'].isna().sum()
    if print_bool:
        print(f'Percentage of dropped rows: {(nan_count / len(inc_df) * 100):.2f}%, '+
               'because these incidents are more than 25 meters from the closest road.')

    # all incidents which are too far away from the network are dropped
    incidents = inc_df.dropna().reset_index(drop=True)
    
    return incidents

# %%
def create_empty_cost_M(uni_cand, inc_df, G):
    """
    Create an empty cost matrix for candidate and incident nodes.

    Args:
        uni_cand (pd.DataFrame): A DataFrame containing candidate node information, including 'Main_updated' and 'Clone_updated'.
        inc_df (pd.DataFrame): The incidents DataFrame.
        G (networkx.Graph): The graph containing road network information.

    Returns:
        pd.DataFrame: An empty cost matrix with candidate nodes as rows and incident nodes as columns.
        list: The column names (incident nodes) extracted from the incidents DataFrame and present in the graph 'G'.
    """

    num_rows = len(uni_cand)
    placeholder_value = None  # You can use np.nan or any other value as a placeholder
    col_names = [str(node) for node in list(inc_df['Node']) if str(node) in G.nodes()]
    main_names = uni_cand['Main_updated'].values
    clone_names = uni_cand['Clone_updated'].values
    num_columns = len(col_names)
    data = [[placeholder_value] * num_columns for _ in range(num_rows)]
    cost_M = pd.DataFrame(data, columns=col_names)
    cost_M.insert(0, 'Main', main_names)
    cost_M.insert(1, 'Clone', clone_names)
    
    return cost_M, col_names

# %%
def parse_coordinate(coordinate_string):
    """
    Parse a string of coordinate values to obtain usable x and y coordinates.

    Args:
        coordinate_string (str): A string containing the coordinate values in the format "(x, y)".

    Returns:
        tuple: A tuple containing the parsed x and y coordinates as floats.
    """
    # Remove parentheses and split the string by comma
    if coordinate_string[-2] == '.':
        coordinate_string = coordinate_string[:-2]
    cleaned_string = coordinate_string.strip('()')
    x_str, y_str = cleaned_string.split(',')

    # Convert the string values to floats
    x = float(x_str.strip())
    y = float(y_str.strip())

    return x, y

# %%
def calculate_cost_matrix(cost_M, G, print_bool=False):
    """
    Fill in all values of the cost matrix based on network distances.

    This function populates the cost matrix with values representing distances or costs between candidate nodes and incident nodes. It uses network-based distances where possible, including Euclidean distance and shortest path lengths, while considering constraints for large distances.

    Args:
        cost_M (pd.DataFrame): An empty cost matrix with candidate nodes as rows and incident nodes as columns.
        G (networkx.Graph): The graph containing road network information.
        print_bool (bool, optional): If True, the function prints the time taken for the calculations. Defaults to False.

    Returns:
        pd.DataFrame: The filled cost matrix with calculated distances or costs between candidate and incident nodes.
    """
    
    t0 = time.time()
    cost_M = cost_M.copy()
    no_counter = 0
    
    for row_idx in range(cost_M.shape[0]):

        main_node = cost_M.iloc[row_idx, 0]
        clone_node = cost_M.iloc[row_idx, 1]

        main_node_x, main_node_y = parse_coordinate(main_node)
        
        for col_idx in np.arange(2, cost_M.shape[1]):

            # store coordinates of incident node as tuple
            goal_node = parse_coordinate(cost_M.columns[col_idx])

            # calculate euclidean distance
            dx = main_node_x - goal_node[0]
            dy = main_node_y - goal_node[1]
            distance = np.sqrt(dx*dx + dy*dy)

            # if euclidean distance is larger than 50 km set a large value as cost
            if distance > 50000:
                cost = 1e9

            # otherwise try to calculate shortest path
            else:
                try:
                    cost_main = nx.shortest_path_length(G, str(main_node), str(goal_node), 
                                                   weight='weight')
                    try:
                        cost_clone = nx.shortest_path_length(G, str(clone_node), str(goal_node), 
                                                       weight='weight')
                    except:
                        cost = cost_main
                    else:
                        # add 2 km to the cost of the clone node and then take min cost
                        cost = np.min([cost_main, cost_clone + 2000])

                # if shortest path still throws an error then store other large value
                except:
                    no_counter += 1
                    cost = 2e9

            # store calculated cost in the correct postion in matrix
            cost_M.iloc[row_idx, col_idx] = cost
            
    t1 = time.time()

    total = t1-t0
    if print_bool:
        print(f'calculating the whole cost matrix took: {total/60:.2f} minutes')
        
    return cost_M

# %%
def drop_unconnected_incidents(cost_M, print_bool=False):
    """
    Remove incidents with excessively large costs from the cost matrix.

    This function removes incidents from the cost matrix if the cost to the nearest candidate node is larger than 1,000 kilometers. 

    Args:
        cost_M (pd.DataFrame): The cost matrix with candidate nodes as rows and incident nodes as columns.
        print_bool (bool, optional): If True, the function prints the percentage of dropped incidents. Defaults to False.

    Returns:
        pd.DataFrame: The cost matrix with unconnected incidents removed.
    """
    cost_M = cost_M.copy()
    
    # get the minimum cost values for each incident node
    min_values = cost_M.iloc[:, 2:].min()
    columns_to_drop = []

    # iterate over al min costs and if this is larger than 1000 km add it to the drop list
    for col, val in min_values.items():
        if pd.notna(val) and val > 1e6:
            columns_to_drop.append(col)

    cost_M.drop(columns=columns_to_drop, inplace=True)
    if print_bool:
        print(f'{(len(columns_to_drop) / len(min_values) * 100):.2f}% of the incidents are '+
              'dropped because there is no route possible from any candidate node')
    
    return cost_M

# %%
def subtract_dist_to_node(cost_M, inc):
    """
    Adjust the cost matrix by subtracting the distance from incidents to their nearest road nodes.

    Args:
        cost_M (pd.DataFrame): A cost matrix with distances or costs between candidate nodes and incidents.
        inc (pd.DataFrame): A DataFrame containing information about incidents, including incident locations and distances to the nearest road nodes.

    Returns:
        pd.DataFrame: An adjusted cost matrix with reduced costs after subtracting distances to nearest road nodes.
        list: A list of incident locations (Dutch RD coordinates).
    """
    incidents_loc = []
    distance_store = []
    result_df = cost_M.copy()  # Create a copy of the DataFrame

    # iterate over all incident nodes
    for name in cost_M.iloc[:, 2:].columns:
        if name[-2] == '.':
            count = int(name[-1])
            N = name[:-2]
        else:
            count = 0
            N = name

        # get the data for the incident node
        match = inc[inc["Node"].astype(str) == N]

        # get the distance from the incident to the end node
        dist = match['Node_distance_to_incident'].values
        distance_to_node = dist[count]

        # get the dutch rd coordinates of the incident
        incident_loc = (match["dutch_rd_x"].values[0], match["dutch_rd_y"].values[0])

        incidents_loc.append(incident_loc)
        distance_store.append(distance_to_node)

    result_df.iloc[:, 2:] -= distance_store
    result_df.iloc[:, 2:] = result_df.iloc[:, 2:].abs()
    
    return result_df, incidents_loc

# %%
def store_cost_matrix_in_arrays(cost_M):
    """
    Store the values in the cost matrix in arrays for candidates and incidents.

    Args:
        cost_M (pd.DataFrame): The cost matrix with candidate nodes as rows and incident nodes as columns.

    Returns:
        np.ndarray: The cost matrix values for distances or costs between candidates and incidents.
        np.ndarray: The coordinates of candidate nodes.
        np.ndarray: The coordinates of incident nodes.
    """
    # store the values in arrays
    cost_matrix = np.array(cost_M.iloc[:, 2:].values)
    final_incidents_nodes = np.array(cost_M.columns[2:])
    final_candidates = np.array(cost_M['Main'].values)

    # store the converted coordinate values into a new array
    candidates = np.array([parse_coordinate(node) for node in final_candidates])
    incidents = np.array([parse_coordinate(node) for node in final_incidents_nodes])
    
    return cost_matrix, candidates, incidents

# %%
def run_gurobi_model(selected_day, cost_M, cand_arr, inc_arr, print_bool=False):
    """
    Create a Gurobi optimization model for assigning inspectors to incidents.

    This function sets up a Gurobi optimization model, adds the objective function and constraints, and then runs the optimization to determine the assignment of inspectors to incidents. It returns the results, including the selected inspector nodes and a binary matrix indicating the assignment of inspectors to incidents.

    Args:
        selected_day (datetime.date): The date for which the optimization is performed.
        cost_M (np.ndarray): A cost matrix with distances or costs between candidate nodes and incidents.
        cand_arr (np.ndarray): Coordinates of candidate nodes.
        inc_arr (np.ndarray): Coordinates of incident nodes.
        print_bool (bool, optional): If True, the function prints summary results. Defaults to False.

    Returns:
        list: A list of results including the selected day, number of inspectors, number of incidents,
              objective function value, average response time (in seconds), and average response time (in minutes).
        list: A list of selected inspector nodes.
        np.ndarray: A binary matrix indicating the assignment of inspectors to incidents.
    """
    # initialise model
    model = Model("Road inspectors")
    
    # Setting up the indices
    N = np.arange(cand_arr.shape[0])
    K = np.arange(inc_arr.shape[0])

    # Parameters
    inspector_cap = 10 # the maximum amount of incidents an inspector can handle in a day
    N_inspectors = 120 # the maximum amount of inspectors
    speed = 100 # a constant speed value in km/h

    if inspector_cap * N_inspectors < inc_arr.shape[0]:
        raise ValueError("Not enough inspectors!")
        
    pair = [(i, k) for i in N for k in K]

    # Setting up the variables
    x = model.addVars(pair, vtype=GRB.BINARY, name="x")
    c = model.addVars(N, vtype=GRB.BINARY, name="c")

    model.Params.MIPGap = 0.01 # set the threshold value at which the optimisation stops to 1.0%
    model.Params.IntegralityFocus=0
    model.update()
    
    # Objective function: Minimise the total travel cost
    model.setObjective(quicksum(cost_M[i, k] * x[i, k] for i in N for k in K),
                       GRB.MINIMIZE)
    
    # Constraints: All incidents must be handled
    model.addConstrs(quicksum(x[i, k] for i in N) == 1 for k in K)
    
    # Constraints: Inspector capacity
    model.addConstrs(quicksum(x[i, k] for k in K) <= (inspector_cap * c[i]) for i in N)
    
    # Constraints: Number of inspectors
    model.addConstr(quicksum(c[i] for i in N) <= N_inspectors)
    
    # Run the model
    model.update()
    model.optimize()
    
    # Collect the results
    inspectors = []



    # Collect the matching
    match_arr = np.zeros((len(N), len(K)))
    for i in N:
        for k in K:
            match_arr[i, k] = x[i, k].x

    for i in N:
        if c[i].x == 1:
            inspectors.append(i)
    
    # Calculate the average response time in seconds
    ave_time = model.ObjVal / len(inc_arr) / 1000 / speed * 3600
    # Collect objective date, number of inspectors, number of incidents,
    # objective function values, average response time[sec], average response time [min]
    output = [selected_day, len(N), len(K),
               model.ObjVal, ave_time, ave_time/60]
            
    # Summary of results
    if print_bool:
        print(f'Minimum total cost is {model.ObjVal/1000:.2f} km')
        print(f'Number of inspectors is {len(inspectors)}')
        print(f'The distance per inspector is {model.ObjVal / len(inspectors) / 1000 :.2f} km')

        
        print(f'Average time to reach the incident is {ave_time//60:.0f} minutes and {ave_time%60:.0f} seconds')
    
    return output, inspectors, match_arr

# %%
def process_inspectors_data(inspectors_df, G):
    """
    Process inspector location data and update it with nearest road nodes.

    Args:
        inspectors_df (pd.DataFrame): DataFrame containing inspector location data.
        G (networkx.Graph): Graph representing road networks for finding nearest road nodes.

    Returns:
        pd.DataFrame: Processed inspector location data with updated coordinates.
    """
    # Rename and select relevant columns
    inspectors_df.rename(columns={'Other_side': 'Clone'}, inplace=True)
    inspectors_df = inspectors_df[['X_value', 'Y_value', 'Clone']]

    # Convert all coordinates to string
    inspectors_df['Main'] = inspectors_df.apply(lambda row: str((row['X_value'], row['Y_value'])), axis=1)
    inspectors_df = inspectors_df[['Main', 'Clone']]

    # Add the coordinates from the find_closest_node function
    inspectors_df['Main_updated'] = inspectors_df['Main'].apply(lambda x: find_closest_node(G, x))
    inspectors_df['Clone_updated'] = inspectors_df['Clone'].apply(lambda x: find_closest_node(G, x))
    
    return inspectors_df

# %%
def run_everything_for_optimisation (selected_day, all_incidents, inspectors_df, G, input_day):
    """
    Run all calculations for the optimization model.

    This function performs a series of calculations and optimization steps for the road inspector allocation model based on the following input parameters:
    
    Args:
        selected_day (datetime.date): The day for which calculations are performed.
        all_incidents (pd.DataFrame): DataFrame containing information about all incidents.
        inspectors_df (pd.DataFrame): DataFrame with inspector location data.
        G (networkx.Graph): Network graph representing road networks.
        input_day (str): The input day used in file naming or other purposes.

    Returns:
        tuple: A tuple containing the following elements:
            - output (list): Results including the number of inspectors, incidents, objective value, average response time in seconds, and average response time in minutes.
            - match_arr (numpy.ndarray): A 2D array representing the assignment of inspectors to incidents.
            - incidents_location (pd.DataFrame): DataFrame containing incident locations.
            - inspectors (list): List of inspector locations selected by the optimization model.
    """
    inspectors_df = process_inspectors_data(inspectors_df, G)
    
    filtered_incidents = filter_incidents(selected_day, all_incidents)

    incidents_results = filtered_incidents.apply(calculate_values, axis=1)
    
    incidents = drop_inc_out_of_range(incidents_results)

    cost_matrix, column_names = create_empty_cost_M(inspectors_df, incidents, G)

    fill_cost_matrix = calculate_cost_matrix(cost_matrix, G)

    clean_cost_matrix = drop_unconnected_incidents(fill_cost_matrix)
    
    end_cost_matrix, incidents_loc = subtract_dist_to_node(clean_cost_matrix, incidents)
    
    incidents_location = pd.DataFrame(incidents_loc, columns=['x', 'y'])

    cost_matrix, candidates, incidents = store_cost_matrix_in_arrays(end_cost_matrix)

    if cost_matrix.shape[0] != candidates.shape[0] or cost_matrix.shape[1] != incidents.shape[0]:
        raise ValueError("Dimensions do not match")

    output, inspectors, match_arr = run_gurobi_model(selected_day, cost_matrix, candidates, incidents, print_bool=True)

    return output, match_arr, incidents_location, inspectors

# %%
def run_calculation_for_all_days(input_days, all_incidents, sums, G, number_of_inspectors, min_range, min_direct_range, name):
    """
    Perform optimization calculations with selected parameter settings for multiple days.

    Args:
        input_days (list of str): A list of date strings in the format 'YYYY-MM-DD' for which the calculations will be performed.
        all_incidents (pd.DataFrame): DataFrame containing information about all incidents.
        sums_with_weight (pd.DataFrame): DataFrame with weighted sums for candidate locations.
        G (networkx.Graph): Network graph representing road networks.
        number_of_inspectors (int): The maximum number of inspectors available.
        min_range (float): The minimum Euclidean distance between inspectors and incidents.
        min_direct_range (float): The minimum direct distance between inspectors and incidents.

    Returns:
        pd.DataFrame: A DataFrame containing the calibration results of the optimization calculations for each input day. Columns include 'Date', 'Number of inspectors', 'Number of Incidents', 'Objective Value', 'Average response time [s]', and 'Average response time [min]'.
    """
    start_time_calculations = time.time()

    dict_match_arr = {}
    dict_incidents_location = {}
    df_obj = pd.DataFrame(columns=['Date', 'Number of inspectors',
                                   'Number of Incidents', 'Objective Value',
                                   'Average response time [s]', 'Average response time [min]'])

    inspectors_df = final_Inspector_locations(sums, number_of_inspectors, min_range, min_direct_range)
    inspectors_df.to_csv(file_path + f"Inspectors__loc_{number_of_inspectors}_{name}_{min_range}_{min_direct_range}.csv")
    for i, day in enumerate(input_days):
        try:
            day_start_time = time.time()

            print(f'running day {i+1} out of {len(input_days)}')

            selected_day = datetime.strptime(day, '%Y-%m-%d').date()

            output, match_arr, incidents_location, inspectors = run_everything_for_optimisation(selected_day, all_incidents, inspectors_df, G, day)
            dict_match_arr[day] = match_arr
            dict_incidents_location[day] = incidents_location
            df_obj.loc[i] = output

            day_end_time = time.time()

            print(f'calculating day {i+1} took: {(day_end_time - day_start_time)/60:.2f} minutes')
        except Exception as e:
            print(f'Error for date: {day}\n{str(e)}')
            continue

    end_time_calculations = time.time()
    print(f'The calculations took: {(end_time_calculations - start_time_calculations)/60:.2f} minutes')

    return df_obj

# %%
for i in range(len(min_ranges)):
    min_range = min_ranges[i]
    min_direct_range = min_direct_ranges[i]
    df_obj = run_calculation_for_all_days(input_days, all_incidents, sums, G, number_of_inspectors, min_range, min_direct_range, name)
    df_obj.to_csv(file_path + f"Results_{number_of_inspectors}_{name}_{min_range}_{min_direct_range}.csv")
# Out:
#        X_value     Y_value  Sum_weight
# 0   157715.969  379454.419          43
# 1    85860.077  432976.598          33
# 2   119810.340  493682.340          32
# 3    95910.015  462530.838          30
# 4   108158.906  450448.650          30
# ..         ...         ...         ...
# 95  103380.091  411755.819          14
# 96  192276.083  450054.322          14
# 97  119624.752  492237.241          14
# 98   96305.000  436627.000          14
# 99  112503.752  481845.111          14
#
# [100 rows x 3 columns]
# running day 1 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 346 rows, 24600 columns and 49200 nonzeros
# Model fingerprint: 0xabdb6c77
# Variable types: 0 continuous, 24600 integer (24600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+02, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 1.650047e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.06s
# Presolved: 345 rows, 24500 columns, 49000 nonzeros
# Variable types: 0 continuous, 24500 integer (24500 binary)
# Found heuristic solution: objective 2.014467e+09
#
# Root relaxation: objective 4.972563e+06, 255 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# *    0     0               0    4972562.9310 4972562.93  0.00%     -    0s
#
# Explored 1 nodes (255 simplex iterations) in 0.11 seconds (0.09 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 4.97256e+06 2.01447e+09 1.65005e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 4.972562931004e+06, best bound 4.972562931004e+06, gap 0.0000%
# Minimum total cost is 4972.56 km
# Number of inspectors is 100
# The distance per inspector is 49.73 km
# Average time to reach the incident is 12 minutes and 11 seconds
# calculating day 1 took: 4.15 minutes
# running day 2 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 541 rows, 44100 columns and 88200 nonzeros
# Model fingerprint: 0xa3fb88d0
# Variable types: 0 continuous, 44100 integer (44100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.060080e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.12s
# Presolved: 540 rows, 44000 columns, 88000 nonzeros
# Variable types: 0 continuous, 44000 integer (44000 binary)
# Found heuristic solution: objective 7.023928e+09
#
# Root relaxation: objective 7.600170e+06, 478 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7600169.5009 7600169.50  0.00%     -    0s
#
# Explored 1 nodes (478 simplex iterations) in 0.22 seconds (0.17 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 7.60017e+06 7.02393e+09 3.06008e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 7.600169500905e+06, best bound 7.600169500905e+06, gap 0.0000%
# Minimum total cost is 7600.17 km
# Number of inspectors is 100
# The distance per inspector is 76.00 km
# Average time to reach the incident is 10 minutes and 22 seconds
# calculating day 2 took: 5.37 minutes
# running day 3 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 662 rows, 56200 columns and 112400 nonzeros
# Model fingerprint: 0x625e0664
# Variable types: 0 continuous, 56200 integer (56200 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.680118e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.15s
# Presolved: 661 rows, 56100 columns, 112200 nonzeros
# Variable types: 0 continuous, 56100 integer (56100 binary)
# Found heuristic solution: objective 1.403022e+10
#
# Root relaxation: objective 2.008511e+09, 621 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2.008511e+09 2.0085e+09  0.00%     -    0s
#
# Explored 1 nodes (621 simplex iterations) in 0.27 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 2.00851e+09 1.40302e+10 3.68012e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.008510773427e+09, best bound 2.008510773427e+09, gap 0.0000%
# Minimum total cost is 2008510.77 km
# Number of inspectors is 100
# The distance per inspector is 20085.11 km
# Average time to reach the incident is 2148 minutes and 8 seconds
# calculating day 3 took: 6.31 minutes
# running day 4 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 668 rows, 56800 columns and 113600 nonzeros
# Model fingerprint: 0xe85741e9
# Variable types: 0 continuous, 56800 integer (56800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.940102e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.13s
# Presolved: 667 rows, 56700 columns, 113400 nonzeros
# Variable types: 0 continuous, 56700 integer (56700 binary)
# Found heuristic solution: objective 1.303035e+10
#
# Root relaxation: objective 1.009780e+09, 637 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.009780e+09 1.0098e+09  0.00%     -    0s
#
# Explored 1 nodes (637 simplex iterations) in 0.23 seconds (0.22 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.00978e+09 1.30304e+10 3.9401e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.009779774652e+09, best bound 1.009779774652e+09, gap 0.0000%
# Minimum total cost is 1009779.77 km
# Number of inspectors is 100
# The distance per inspector is 10097.80 km
# Average time to reach the incident is 1068 minutes and 33 seconds
# calculating day 4 took: 5.94 minutes
# running day 5 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 826 rows, 72600 columns and 145200 nonzeros
# Model fingerprint: 0x82e8581f
# Variable types: 0 continuous, 72600 integer (72600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4.800141e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.18s
# Presolved: 825 rows, 72500 columns, 145000 nonzeros
# Variable types: 0 continuous, 72500 integer (72500 binary)
# Found heuristic solution: objective 2.403637e+10
#
# Root relaxation: objective 7.012589e+09, 919 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7.012589e+09 7.0126e+09  0.00%     -    0s
#
# Explored 1 nodes (919 simplex iterations) in 0.35 seconds (0.29 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 7.01259e+09 2.40364e+10 4.80014e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 7.012588886965e+09, best bound 7.012588886965e+09, gap 0.0000%
# Minimum total cost is 7012588.89 km
# Number of inspectors is 100
# The distance per inspector is 70125.89 km
# Average time to reach the incident is 5803 minutes and 31 seconds
# calculating day 5 took: 5.85 minutes
# running day 6 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 619 rows, 51900 columns and 103800 nonzeros
# Model fingerprint: 0x04f622ad
# Variable types: 0 continuous, 51900 integer (51900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.360106e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.14s
# Presolved: 618 rows, 51800 columns, 103600 nonzeros
# Variable types: 0 continuous, 51800 integer (51800 binary)
# Found heuristic solution: objective 9.027716e+09
#
# Root relaxation: objective 8.070541e+06, 541 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8070540.5083 8070540.51  0.00%     -    0s
#
# Explored 1 nodes (541 simplex iterations) in 0.23 seconds (0.20 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 8.07054e+06 9.02772e+09 3.36011e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 8.070540508307e+06, best bound 8.070540508307e+06, gap 0.0000%
# Minimum total cost is 8070.54 km
# Number of inspectors is 100
# The distance per inspector is 80.71 km
# Average time to reach the incident is 9 minutes and 21 seconds
# calculating day 6 took: 5.30 minutes
# running day 7 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 663 rows, 56300 columns and 112600 nonzeros
# Model fingerprint: 0x69ec6f88
# Variable types: 0 continuous, 56300 integer (56300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.700107e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.13s
# Presolved: 662 rows, 56200 columns, 112400 nonzeros
# Variable types: 0 continuous, 56200 integer (56200 binary)
# Found heuristic solution: objective 7.029495e+09
#
# Root relaxation: objective 1.009248e+09, 630 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.009248e+09 1.0092e+09  0.00%     -    0s
#
# Explored 1 nodes (630 simplex iterations) in 0.25 seconds (0.22 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.00925e+09 7.02949e+09 3.70011e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.009248141299e+09, best bound 1.009248141299e+09, gap 0.0000%
# Minimum total cost is 1009248.14 km
# Number of inspectors is 100
# The distance per inspector is 10092.48 km
# Average time to reach the incident is 1077 minutes and 29 seconds
# calculating day 7 took: 5.28 minutes
# running day 8 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 835 rows, 73500 columns and 147000 nonzeros
# Model fingerprint: 0x230b7d42
# Variable types: 0 continuous, 73500 integer (73500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4.890146e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.26s
# Presolved: 834 rows, 73400 columns, 146800 nonzeros
# Variable types: 0 continuous, 73400 integer (73400 binary)
# Found heuristic solution: objective 1.303983e+10
#
# Root relaxation: objective 1.298822e+07, 983 iterations, 0.05 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.298822e+07 1.2988e+07  0.00%     -    0s
#
# Explored 1 nodes (983 simplex iterations) in 0.52 seconds (0.31 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.29882e+07 1.30398e+10 4.89015e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.298821756743e+07, best bound 1.298821756743e+07, gap 0.0000%
# Minimum total cost is 12988.22 km
# Number of inspectors is 100
# The distance per inspector is 129.88 km
# Average time to reach the incident is 10 minutes and 37 seconds
# calculating day 8 took: 6.50 minutes
# running day 9 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 994 rows, 89400 columns and 178800 nonzeros
# Model fingerprint: 0x433b05f5
# Variable types: 0 continuous, 89400 integer (89400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 5.720201e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.32s
# Presolved: 993 rows, 89300 columns, 178600 nonzeros
# Variable types: 0 continuous, 89300 integer (89300 binary)
# Found heuristic solution: objective 3.504646e+10
#
# Root relaxation: objective 2.018521e+09, 1583 iterations, 0.10 seconds (0.06 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2.018521e+09 2.0185e+09  0.00%     -    0s
#
# Explored 1 nodes (1583 simplex iterations) in 0.64 seconds (0.42 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 2.01852e+09 3.50465e+10 5.7202e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.018520881646e+09, best bound 2.018520881646e+09, gap 0.0000%
# Minimum total cost is 2018520.88 km
# Number of inspectors is 100
# The distance per inspector is 20185.21 km
# Average time to reach the incident is 1356 minutes and 14 seconds
# calculating day 9 took: 8.87 minutes
# running day 10 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 763 rows, 66300 columns and 132600 nonzeros
# Model fingerprint: 0xc6626908
# Variable types: 0 continuous, 66300 integer (66300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4.180141e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.21s
# Presolved: 762 rows, 66200 columns, 132400 nonzeros
# Variable types: 0 continuous, 66200 integer (66200 binary)
# Found heuristic solution: objective 9.034135e+09
#
# Root relaxation: objective 1.013902e+07, 775 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.013902e+07 1.0139e+07  0.00%     -    0s
#
# Explored 1 nodes (775 simplex iterations) in 0.36 seconds (0.26 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.0139e+07 9.03413e+09 4.18014e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.013902000385e+07, best bound 1.013902000385e+07, gap 0.0000%
# Minimum total cost is 10139.02 km
# Number of inspectors is 100
# The distance per inspector is 101.39 km
# Average time to reach the incident is 9 minutes and 11 seconds
# calculating day 10 took: 7.43 minutes
# running day 11 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 686 rows, 58600 columns and 117200 nonzeros
# Model fingerprint: 0x475e2b7f
# Variable types: 0 continuous, 58600 integer (58600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.810125e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.19s
# Presolved: 685 rows, 58500 columns, 117000 nonzeros
# Variable types: 0 continuous, 58500 integer (58500 binary)
# Found heuristic solution: objective 8.031277e+09
#
# Root relaxation: objective 9.132165e+06, 652 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    9132164.6668 9132164.67  0.00%     -    0s
#
# Explored 1 nodes (652 simplex iterations) in 0.38 seconds (0.23 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 9.13216e+06 8.03128e+09 3.81013e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 9.132164666806e+06, best bound 9.132164666806e+06, gap 0.0000%
# Minimum total cost is 9132.16 km
# Number of inspectors is 100
# The distance per inspector is 91.32 km
# Average time to reach the incident is 9 minutes and 22 seconds
# calculating day 11 took: 7.08 minutes
# running day 12 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 663 rows, 56300 columns and 112600 nonzeros
# Model fingerprint: 0x554af552
# Variable types: 0 continuous, 56300 integer (56300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.730105e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.16s
# Presolved: 662 rows, 56200 columns, 112400 nonzeros
# Variable types: 0 continuous, 56200 integer (56200 binary)
# Found heuristic solution: objective 5.030423e+09
#
# Root relaxation: objective 8.860793e+06, 611 iterations, 0.00 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8860793.3844 8860793.38  0.00%     -    0s
#
# Explored 1 nodes (611 simplex iterations) in 0.30 seconds (0.22 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 8.86079e+06 5.03042e+09 3.7301e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 8.860793384428e+06, best bound 8.860793384428e+06, gap 0.0000%
# Minimum total cost is 8860.79 km
# Number of inspectors is 100
# The distance per inspector is 88.61 km
# Average time to reach the incident is 9 minutes and 28 seconds
# calculating day 12 took: 6.80 minutes
# running day 13 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 704 rows, 60400 columns and 120800 nonzeros
# Model fingerprint: 0xca11808f
# Variable types: 0 continuous, 60400 integer (60400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.920126e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.19s
# Presolved: 703 rows, 60300 columns, 120600 nonzeros
# Variable types: 0 continuous, 60300 integer (60300 binary)
# Found heuristic solution: objective 1.003206e+10
#
# Root relaxation: objective 1.011094e+09, 726 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.011094e+09 1.0111e+09  0.00%     -    0s
#
# Explored 1 nodes (726 simplex iterations) in 0.35 seconds (0.24 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.01109e+09 1.00321e+10 3.92013e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.011094189697e+09, best bound 1.011094189697e+09, gap 0.0000%
# Minimum total cost is 1011094.19 km
# Number of inspectors is 100
# The distance per inspector is 10110.94 km
# Average time to reach the incident is 1006 minutes and 4 seconds
# calculating day 13 took: 6.95 minutes
# running day 14 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 501 rows, 40100 columns and 80200 nonzeros
# Model fingerprint: 0x6cf870c1
# Variable types: 0 continuous, 40100 integer (40100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.860078e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.18s
# Presolved: 500 rows, 40000 columns, 80000 nonzeros
# Variable types: 0 continuous, 40000 integer (40000 binary)
# Found heuristic solution: objective 5.023432e+09
# Root relaxation: objective 6.773640e+06, 415 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    6773640.0837 6773640.08  0.00%     -    0s
#
# Explored 1 nodes (415 simplex iterations) in 0.29 seconds (0.15 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 6.77364e+06 5.02343e+09 2.86008e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 6.773640083727e+06, best bound 6.773640083727e+06, gap 0.0000%
# Minimum total cost is 6773.64 km
# Number of inspectors is 100
# The distance per inspector is 67.74 km
# Average time to reach the incident is 10 minutes and 10 seconds
# calculating day 14 took: 5.94 minutes
# running day 15 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 685 rows, 58500 columns and 117000 nonzeros
# Model fingerprint: 0x312c9247
# Variable types: 0 continuous, 58500 integer (58500 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.850124e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.14s
# Presolved: 684 rows, 58400 columns, 116800 nonzeros
# Variable types: 0 continuous, 58400 integer (58400 binary)
# Found heuristic solution: objective 5.031484e+09
#
# Root relaxation: objective 8.583328e+06, 640 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8583328.3238 8583328.32  0.00%     -    0s
#
# Explored 1 nodes (640 simplex iterations) in 0.23 seconds (0.23 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 8.58333e+06 5.03148e+09 3.85012e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 8.583328323755e+06, best bound 8.583328323755e+06, gap 0.0000%
# Minimum total cost is 8583.33 km
# Number of inspectors is 100
# The distance per inspector is 85.83 km
# Average time to reach the incident is 8 minutes and 49 seconds
# calculating day 15 took: 5.58 minutes
# running day 16 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 720 rows, 62000 columns and 124000 nonzeros
# Model fingerprint: 0xbb363f8c
# Variable types: 0 continuous, 62000 integer (62000 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.780143e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.16s
# Presolved: 719 rows, 61900 columns, 123800 nonzeros
# Variable types: 0 continuous, 61900 integer (61900 binary)
# Found heuristic solution: objective 6.031985e+09
#
# Root relaxation: objective 2.009903e+09, 739 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    2.009903e+09 2.0099e+09  0.00%     -    0s
#
# Explored 1 nodes (739 simplex iterations) in 0.28 seconds (0.24 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 2.0099e+09 6.03198e+09 3.78014e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 2.009903011001e+09, best bound 2.009903011001e+09, gap 0.0000%
# Minimum total cost is 2009903.01 km
# Number of inspectors is 100
# The distance per inspector is 20099.03 km
# Average time to reach the incident is 1948 minutes and 13 seconds
# calculating day 16 took: 5.23 minutes
# running day 17 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 576 rows, 47600 columns and 95200 nonzeros
# Model fingerprint: 0x0d9c94db
# Variable types: 0 continuous, 47600 integer (47600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.190090e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.09s
# Presolved: 575 rows, 47500 columns, 95000 nonzeros
# Variable types: 0 continuous, 47500 integer (47500 binary)
# Found heuristic solution: objective 1.802532e+10
#
# Root relaxation: objective 9.007050e+09, 525 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    9.007050e+09 9.0070e+09  0.00%     -    0s
#
# Explored 1 nodes (525 simplex iterations) in 0.19 seconds (0.18 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 9.00705e+09 1.80253e+10 3.19009e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 9.007049743045e+09, best bound 9.007049743045e+09, gap 0.0000%
# Minimum total cost is 9007049.74 km
# Number of inspectors is 100
# The distance per inspector is 90070.50 km
# Average time to reach the incident is 11377 minutes and 20 seconds
# calculating day 17 took: 4.74 minutes
# running day 18 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 798 rows, 69800 columns and 139600 nonzeros
# Model fingerprint: 0x11715fd0
# Variable types: 0 continuous, 69800 integer (69800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4.480141e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.18s
# Presolved: 797 rows, 69700 columns, 139400 nonzeros
# Variable types: 0 continuous, 69700 integer (69700 binary)
# Found heuristic solution: objective 1.503592e+10
#
# Root relaxation: objective 6.011214e+09, 858 iterations, 0.03 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    6.011214e+09 6.0112e+09  0.00%     -    0s
#
# Explored 1 nodes (858 simplex iterations) in 0.32 seconds (0.28 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 6.01121e+09 1.50359e+10 4.48014e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 6.011213804761e+09, best bound 6.011213804761e+09, gap 0.0000%
# Minimum total cost is 6011213.80 km
# Number of inspectors is 100
# The distance per inspector is 60112.14 km
# Average time to reach the incident is 5174 minutes and 39 seconds
# calculating day 18 took: 5.56 minutes
# running day 19 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 427 rows, 32700 columns and 65400 nonzeros
# Model fingerprint: 0xea5f9daa
# Variable types: 0 continuous, 32700 integer (32700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.160060e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.08s
# Presolved: 426 rows, 32600 columns, 65200 nonzeros
# Variable types: 0 continuous, 32600 integer (32600 binary)
# Found heuristic solution: objective 1.016973e+09
#
# Root relaxation: objective 5.230610e+06, 351 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5230609.8292 5230609.83  0.00%     -    0s
#
# Explored 1 nodes (351 simplex iterations) in 0.13 seconds (0.12 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 5.23061e+06 1.01697e+09 2.16006e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 5.230609829237e+06, best bound 5.230609829237e+06, gap 0.0000%
# Minimum total cost is 5230.61 km
# Number of inspectors is 100
# The distance per inspector is 52.31 km
# Average time to reach the incident is 9 minutes and 38 seconds
# calculating day 19 took: 3.88 minutes
# running day 20 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 651 rows, 55100 columns and 110200 nonzeros
# Model fingerprint: 0x4792b703
# Variable types: 0 continuous, 55100 integer (55100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.760097e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.14s
# Presolved: 650 rows, 55000 columns, 110000 nonzeros
# Variable types: 0 continuous, 55000 integer (55000 binary)
# Found heuristic solution: objective 1.702797e+10
#
# Root relaxation: objective 5.010755e+09, 634 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5.010755e+09 5.0108e+09  0.00%     -    0s
#
# Explored 1 nodes (634 simplex iterations) in 0.25 seconds (0.21 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 5.01076e+09 1.7028e+10 3.7601e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 5.010755404845e+09, best bound 5.010755404845e+09, gap 0.0000%
# Minimum total cost is 5010755.40 km
# Number of inspectors is 100
# The distance per inspector is 50107.55 km
# Average time to reach the incident is 5466 minutes and 17 seconds
# calculating day 20 took: 5.14 minutes
# The calculations took: 121.46 minutes
#          X_value       Y_value  Sum_weight
# 0   157715.96900  379454.41900          43
# 1    85860.07700  432976.59800          33
# 2   119810.34000  493682.34000          32
# 3    95910.01500  462530.83800          30
# 4   108158.90600  450448.65000          30
# ..           ...           ...         ...
# 95   74185.71400  435604.22900          14
# 96  101902.78000  467822.42000          14
# 97  176751.32100  381498.28300          14
# 98  201821.75800  567217.87900          13
# 99  138339.34429  451620.33107          13
#
# [100 rows x 3 columns]
# running day 1 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 348 rows, 24800 columns and 49600 nonzeros
# Model fingerprint: 0xdf1b2144
# Variable types: 0 continuous, 24800 integer (24800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+02, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 1.730043e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.06s
# Presolved: 347 rows, 24700 columns, 49400 nonzeros
# Variable types: 0 continuous, 24700 integer (24700 binary)
# Found heuristic solution: objective 4.013124e+09
#
# Root relaxation: objective 3.790221e+06, 255 iterations, 0.00 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3790220.9928 3790220.99  0.00%     -    0s
#
# Explored 1 nodes (255 simplex iterations) in 0.13 seconds (0.09 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 3.79022e+06 4.01312e+09 1.73004e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.790220992788e+06, best bound 3.790220992788e+06, gap 0.0000%
# Minimum total cost is 3790.22 km
# Number of inspectors is 100
# The distance per inspector is 37.90 km
# Average time to reach the incident is 9 minutes and 12 seconds
# calculating day 1 took: 3.67 minutes
# running day 2 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 544 rows, 44400 columns and 88800 nonzeros
# Model fingerprint: 0xc09ab35c
# Variable types: 0 continuous, 44400 integer (44400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.880096e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.11s
# Presolved: 543 rows, 44300 columns, 88600 nonzeros
# Variable types: 0 continuous, 44300 integer (44300 binary)
# Found heuristic solution: objective 5.025378e+09
#
# Root relaxation: objective 7.215104e+06, 485 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    7215104.4920 7215104.49  0.00%     -    0s
#
# Explored 1 nodes (485 simplex iterations) in 0.20 seconds (0.17 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 7.2151e+06 5.02538e+09 2.8801e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 7.215104492006e+06, best bound 7.215104492006e+06, gap 0.0000%
# Minimum total cost is 7215.10 km
# Number of inspectors is 100
# The distance per inspector is 72.15 km
# Average time to reach the incident is 9 minutes and 46 seconds
# calculating day 2 took: 4.57 minutes
# running day 3 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 668 rows, 56800 columns and 113600 nonzeros
# Model fingerprint: 0xf68af0fd
# Variable types: 0 continuous, 56800 integer (56800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.930101e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.13s
# Presolved: 667 rows, 56700 columns, 113400 nonzeros
# Variable types: 0 continuous, 56700 integer (56700 binary)
# Found heuristic solution: objective 1.003135e+10
#
# Root relaxation: objective 8.140471e+06, 619 iterations, 0.02 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8140471.3194 8140471.32  0.00%     -    0s
#
# Explored 1 nodes (619 simplex iterations) in 0.22 seconds (0.22 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 8.14047e+06 1.00313e+10 3.9301e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 8.140471319406e+06, best bound 8.140471319406e+06, gap 0.0000%
# Minimum total cost is 8140.47 km
# Number of inspectors is 100
# The distance per inspector is 81.40 km
# Average time to reach the incident is 8 minutes and 37 seconds
# calculating day 3 took: 5.18 minutes
# running day 4 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 671 rows, 57100 columns and 114200 nonzeros
# Model fingerprint: 0x15997435
# Variable types: 0 continuous, 57100 integer (57100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.990106e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.14s
# Presolved: 670 rows, 57000 columns, 114000 nonzeros
# Variable types: 0 continuous, 57000 integer (57000 binary)
# Found heuristic solution: objective 1.203097e+10
#
# Root relaxation: objective 8.676638e+06, 641 iterations, 0.01 seconds (0.01 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8676637.8495 8676637.85  0.00%     -    0s
#
# Explored 1 nodes (641 simplex iterations) in 0.23 seconds (0.22 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 8.67664e+06 1.2031e+10 3.99011e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 8.676637849505e+06, best bound 8.676637849505e+06, gap 0.0000%
# Minimum total cost is 8676.64 km
# Number of inspectors is 100
# The distance per inspector is 86.77 km
# Average time to reach the incident is 9 minutes and 8 seconds
# calculating day 4 took: 5.10 minutes
# running day 5 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 831 rows, 73100 columns and 146200 nonzeros
# Model fingerprint: 0xa218b0b3
# Variable types: 0 continuous, 73100 integer (73100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 5.130128e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.19s
# Presolved: 830 rows, 73000 columns, 146000 nonzeros
# Variable types: 0 continuous, 73000 integer (73000 binary)
# Found heuristic solution: objective 3.003626e+10
#
# Root relaxation: objective 1.012082e+09, 915 iterations, 0.03 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.012082e+09 1.0121e+09  0.00%     -    0s
#
# Explored 1 nodes (915 simplex iterations) in 0.36 seconds (0.30 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.01208e+09 3.00363e+10 5.13013e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.012081859960e+09, best bound 1.012081859960e+09, gap 0.0000%
# Minimum total cost is 1012081.86 km
# Number of inspectors is 100
# The distance per inspector is 10120.82 km
# Average time to reach the incident is 831 minutes and 51 seconds
# calculating day 5 took: 5.55 minutes
# running day 6 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 621 rows, 52100 columns and 104200 nonzeros
# Model fingerprint: 0xfab4c412
# Variable types: 0 continuous, 52100 integer (52100 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# ...
#          to avoid numerical issues.
# Found heuristic solution: objective 4.630068e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.14s
# Presolved: 669 rows, 56900 columns, 113800 nonzeros
# Variable types: 0 continuous, 56900 integer (56900 binary)
# Found heuristic solution: objective 1.203316e+10
#
# Root relaxation: objective 9.063494e+06, 1012 iterations, 0.05 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    9063493.5468 9063493.55  0.00%     -    0s
#
# Explored 1 nodes (1012 simplex iterations) in 0.30 seconds (0.25 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 9.06349e+06 1.20332e+10 4.63007e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 9.063493546791e+06, best bound 9.063493546791e+06, gap 0.0000%
# Minimum total cost is 9063.49 km
# Number of inspectors is 100
# The distance per inspector is 90.63 km
# Average time to reach the incident is 9 minutes and 33 seconds
# calculating day 12 took: 4.42 minutes
# running day 13 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 706 rows, 60600 columns and 121200 nonzeros
# Model fingerprint: 0x98c25412
# Variable types: 0 continuous, 60600 integer (60600 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4.790083e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.14s
# Presolved: 705 rows, 60500 columns, 121000 nonzeros
# Variable types: 0 continuous, 60500 integer (60500 binary)
# Found heuristic solution: objective 6.036729e+09
#
# Root relaxation: objective 9.789796e+06, 1080 iterations, 0.05 seconds (0.05 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    9789795.7581 9789795.76  0.00%     -    0s
#
# Explored 1 nodes (1080 simplex iterations) in 0.28 seconds (0.28 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 9.7898e+06 6.03673e+09 4.79008e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 9.789795758111e+06, best bound 9.789795758111e+06, gap 0.0000%
# Minimum total cost is 9789.80 km
# Number of inspectors is 100
# The distance per inspector is 97.90 km
# Average time to reach the incident is 9 minutes and 43 seconds
# calculating day 13 took: 4.56 minutes
# running day 14 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 504 rows, 40400 columns and 80800 nonzeros
# Model fingerprint: 0x480f7000
# Variable types: 0 continuous, 40400 integer (40400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [8e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.260048e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.09s
# Presolved: 503 rows, 40300 columns, 80600 nonzeros
# Variable types: 0 continuous, 40300 integer (40300 binary)
# Found heuristic solution: objective 7.024162e+09
#
# Root relaxation: objective 5.159014e+06, 460 iterations, 0.02 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    5159013.7878 5159013.79  0.00%     -    0s
#
# Explored 1 nodes (460 simplex iterations) in 0.16 seconds (0.15 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 5.15901e+06 7.02416e+09 3.26005e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 5.159013787840e+06, best bound 5.159013787840e+06, gap 0.0000%
# Minimum total cost is 5159.01 km
# Number of inspectors is 100
# The distance per inspector is 51.59 km
# Average time to reach the incident is 7 minutes and 41 seconds
# calculating day 14 took: 3.97 minutes
# running day 15 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 693 rows, 59300 columns and 118600 nonzeros
# Model fingerprint: 0x6ed00c1e
# Variable types: 0 continuous, 59300 integer (59300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [3e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4.760070e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.14s
# Presolved: 692 rows, 59200 columns, 118400 nonzeros
# Variable types: 0 continuous, 59200 integer (59200 binary)
# Found heuristic solution: objective 1.103252e+10
#
# Root relaxation: objective 9.368442e+06, 1064 iterations, 0.05 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    9368442.3797 9368442.38  0.00%     -    0s
#
# Explored 1 nodes (1064 simplex iterations) in 0.30 seconds (0.27 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 9.36844e+06 1.10325e+10 4.76007e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 9.368442379711e+06, best bound 9.368442379711e+06, gap 0.0000%
# Minimum total cost is 9368.44 km
# Number of inspectors is 100
# The distance per inspector is 93.68 km
# Average time to reach the incident is 9 minutes and 30 seconds
# calculating day 15 took: 4.54 minutes
# running day 16 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 734 rows, 63400 columns and 126800 nonzeros
# Model fingerprint: 0x5fb6ddd1
# Variable types: 0 continuous, 63400 integer (63400 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [4e+00, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 5.100081e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.16s
# Presolved: 733 rows, 63300 columns, 126600 nonzeros
# Variable types: 0 continuous, 63300 integer (63300 binary)
# Found heuristic solution: objective 1.003548e+10
#
# Root relaxation: objective 1.144908e+07, 1448 iterations, 0.06 seconds (0.08 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.144908e+07 1.1449e+07  0.00%     -    0s
#
# Explored 1 nodes (1448 simplex iterations) in 0.31 seconds (0.32 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.14491e+07 1.00355e+10 5.10008e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.144908059888e+07, best bound 1.144908059888e+07, gap 0.0000%
# Minimum total cost is 11449.08 km
# Number of inspectors is 100
# The distance per inspector is 114.49 km
# Average time to reach the incident is 10 minutes and 51 seconds
# calculating day 16 took: 4.52 minutes
# running day 17 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 583 rows, 48300 columns and 96600 nonzeros
# Model fingerprint: 0xf8ed6f78
# Variable types: 0 continuous, 48300 integer (48300 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [1e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 3.820063e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.13s
# Presolved: 582 rows, 48200 columns, 96400 nonzeros
# Variable types: 0 continuous, 48200 integer (48200 binary)
# Found heuristic solution: objective 1.002750e+10
#
# Root relaxation: objective 6.936356e+06, 789 iterations, 0.02 seconds (0.02 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    6936355.8284 6936355.83  0.00%     -    0s
#
# Explored 1 nodes (789 simplex iterations) in 0.20 seconds (0.20 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 6.93636e+06 1.00275e+10 3.82006e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 6.936355828390e+06, best bound 6.936355828390e+06, gap 0.0000%
# Minimum total cost is 6936.36 km
# Number of inspectors is 100
# The distance per inspector is 69.36 km
# Average time to reach the incident is 8 minutes and 38 seconds
# calculating day 17 took: 4.18 minutes
# running day 18 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 808 rows, 70800 columns and 141600 nonzeros
# Model fingerprint: 0x073b6aa2
# Variable types: 0 continuous, 70800 integer (70800 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [2e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 5.700085e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.19s
# Presolved: 807 rows, 70700 columns, 141400 nonzeros
# Variable types: 0 continuous, 70700 integer (70700 binary)
# Found heuristic solution: objective 1.403946e+10
#
# Root relaxation: objective 1.457829e+07, 2249 iterations, 0.16 seconds (0.21 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    1.457829e+07 1.4578e+07  0.00%     -    0s
#
# Explored 1 nodes (2249 simplex iterations) in 0.44 seconds (0.49 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 1.45783e+07 1.40395e+10 5.70009e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 1.457828635660e+07, best bound 1.457828635660e+07, gap 0.0000%
# Minimum total cost is 14578.29 km
# Number of inspectors is 100
# The distance per inspector is 145.78 km
# Average time to reach the incident is 12 minutes and 22 seconds
# calculating day 18 took: 4.74 minutes
# running day 19 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 429 rows, 32900 columns and 65800 nonzeros
# Model fingerprint: 0xc0d54280
# Variable types: 0 continuous, 32900 integer (32900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [7e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 2.610036e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.08s
# Presolved: 428 rows, 32800 columns, 65600 nonzeros
# Variable types: 0 continuous, 32800 integer (32800 binary)
# Found heuristic solution: objective 1.016521e+09
#
# Root relaxation: objective 3.757077e+06, 379 iterations, 0.01 seconds (0.00 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    3757076.7558 3757076.76  0.00%     -    0s
#
# Explored 1 nodes (379 simplex iterations) in 0.15 seconds (0.13 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 3.75708e+06 1.01652e+09 2.61004e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 3.757076755819e+06, best bound 3.757076755819e+06, gap 0.0000%
# Minimum total cost is 3757.08 km
# Number of inspectors is 100
# The distance per inspector is 37.57 km
# Average time to reach the incident is 6 minutes and 52 seconds
# calculating day 19 took: 3.63 minutes
# running day 20 out of 20
# Set parameter MIPGap to value 0.01
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
#
# CPU model: Intel(R) Core(TM) i7-8750H CPU @ 2.20GHz, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
#
# Optimize a model with 659 rows, 55900 columns and 111800 nonzeros
# Model fingerprint: 0xb53064be
# Variable types: 0 continuous, 55900 integer (55900 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+01]
#   Objective range  [5e+01, 2e+09]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+02]
# Warning: Model contains large objective coefficients
#          Consider reformulating model or setting NumericFocus parameter
#          to avoid numerical issues.
# Found heuristic solution: objective 4.690059e+11
# Presolve removed 1 rows and 100 columns
# Presolve time: 0.14s
# Presolved: 658 rows, 55800 columns, 111600 nonzeros
# Variable types: 0 continuous, 55800 integer (55800 binary)
# Found heuristic solution: objective 1.403191e+10
#
# Root relaxation: objective 8.478208e+06, 909 iterations, 0.04 seconds (0.03 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
# *    0     0               0    8478207.5263 8478207.53  0.00%     -    0s
#
# Explored 1 nodes (909 simplex iterations) in 0.26 seconds (0.23 work units)
# Thread count was 12 (of 12 available processors)
#
# Solution count 3: 8.47821e+06 1.40319e+10 4.69006e+11
#
# Optimal solution found (tolerance 1.00e-02)
# Best objective 8.478207526301e+06, best bound 8.478207526301e+06, gap 0.0000%
# Minimum total cost is 8478.21 km
# Number of inspectors is 100
# The distance per inspector is 84.78 km
# Average time to reach the incident is 9 minutes and 7 seconds
# calculating day 20 took: 4.50 minutes
# The calculations took: 99.87 minutes
